# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.io as pio  
import plotly.express as px  
import plotly.graph_objects as go  
import plotly.figure_factory as ff  
from plotly.subplots import make_subplots  
from plotly.validators.scatter.marker import SymbolValidator

# %%
from importlib_metadata import version
print(version('numpy'))
# Out:
# 1.19.4

# %%
df = pd.read_csv('_29cm.csv' )

# %%
df
# Out:
#          Unnamed: 0 event_datatime   event_name device_type mobile_brand_name  \
# 0                 0     2021-06-03   click_item      mobile           Samsung
# 1                 1     2021-06-03  add_to_cart      mobile           Samsung
# 2                 2     2021-06-03   click_item      mobile             Apple
# 3                 3     2021-06-03   click_item      mobile             Apple
# 4                 4     2021-06-03  add_to_cart      mobile           Samsung
# ...             ...            ...          ...         ...               ...
# 5880402     5880402     2021-08-04   click_item      mobile             Apple
# 5880403     5880403     2021-08-04   click_item      mobile             Apple
# 5880404     5880404     2021-08-04   click_item      mobile             Apple
# 5880405     5880405     2021-08-04   click_item      mobile           Samsung
# 5880406     5880406     2021-08-04   click_item      mobile             Apple
#
# ...

# %%
df[['event_name']].isnull().sum()
# Out:
# event_name    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5880407 entries, 0 to 5880406
# Data columns (total 20 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   Unnamed: 0                int64
#  1   event_datatime            object
#  2   event_name                object
#  3   device_type               object
#  4   mobile_brand_name         object
#  5   mobile_model_name         object
#  6   mobile_marketing_name     object
#  7   operating_system_version  object
#  8   country                   object
#  9   region                    object
#  10  platform                  object
#  11  item_name                 object
#  12  price                     float64
#  13  category1_name            object
#  14  category2_name            object
#  15  category3_name            object
#  16  brand_name                object
#  17  age                       int64
#  18  gender                    object
#  19  birth_date                object
# ...

# %%
df['brand_name'].value_counts()
df.to_csv('EDA_project2.csv' , mode="w")

# %%
df['brand_name'].value_counts()
# Out:
# LENINA             71609
# THOMASMORE         70942
# FACADE PATTERN     62855
# Mardi Mercredi     61839
# DUNST              61273
#                    ...
# CALVIN KLEIN_건원        1
# 겐조                     1
# 하예진_무료                 1
# ACIDBLACK              1
# CHANEL_에스엠케이           1
# Name: brand_name, Length: 7857, dtype: int64

# %%
df['brand_name'].value_counts()[:110]
# Out:
# LENINA              71609
# THOMASMORE          70942
# FACADE PATTERN      62855
# Mardi Mercredi      61839
# DUNST               61273
#                     ...
# BIRKENSTOCK_브랑토리    11163
# BALANSA (매입)        11127
# CERTO               11055
# ETMON               11028
# CHUBASCO            10883
# Name: brand_name, Length: 110, dtype: int64

# %%
df['age'].value_counts()
# Out:
# 29     321278
# 30     320307
# 31     314136
# 28     301931
# 32     299858
#         ...
# 100         2
# 13          2
# 91          1
# 9           1
# 11          1
# Name: age, Length: 92, dtype: int64

# %%
if df['age'].value_counts() == 1 and 2:
    d

# %%
df['brand_name'].value_counts().plot(kind='barh', figsize=(12,6))
# Out:
# <AxesSubplot: >
# C:\Users\JH KIM\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 50547 (\N{HANGUL SYLLABLE AES}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\JH KIM\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 53076 (\N{HANGUL SYLLABLE KO}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\JH KIM\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 45320 (\N{HANGUL SYLLABLE NEO}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\JH KIM\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 50536 (\N{HANGUL SYLLABLE AEL}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\JH KIM\anaconda3\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   func(*args, **kwargs)
# ...

# %%
df['brand_name'].value_counts()[:8].plot(kind='barh', figsize=(40,20))
# Out:
# <AxesSubplot: >

# %%
plt.figure(figsize = (12, 6))
sns.histplot(data = df[~(df['brand_name'] == 'Brand')], x = 'age', bins = 30,
                        hue = 'brand_name', multiple = 'stack', palette = 'Set2')
plt.show()
# Out:
# C:\Users\JH KIM\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54045 (\N{HANGUL SYLLABLE PAB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\JH KIM\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48120 (\N{HANGUL SYLLABLE MI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\JH KIM\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54644 (\N{HANGUL SYLLABLE HAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\JH KIM\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 48652 (\N{HANGUL SYLLABLE BEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\JH KIM\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 46300 (\N{HANGUL SYLLABLE DEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
df.sort_values(by='total', ascending=False).groupby('brand_name').head(10)
